# %% [markdown]
# <a href="https://colab.research.google.com/github/NoOne6357/portfolio_Harmony-IT/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 5])

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# dtype: int64

# %%
nom = pd.Series(["Harmony", "Sarah", "Kiki", "Sally"])

# %%
print(nom)
# Out:
# 0    Harmony
# 1      Sarah
# 2       Kiki
# 3      Sally
# dtype: object

# %%
apprenants = {'Nom': ['Harmony','Sarah','Kiki','Sally','Geoffrey','Khloranne'],
              'âge':[28,25,27,23,29,24],
              'Ville':['Kinshasa','Goma','Kigali','Mbandaka','Bukavu','Kinshasa'],
              'Sexe':['M','F','F','F','M','F']
              }
pd.DataFrame(apprenants)
# Out:
#          Nom  âge     Ville Sexe
# 0    Harmony   28  Kinshasa    M
# 1      Sarah   25      Goma    F
# 2       Kiki   27    Kigali    F
# 3      Sally   23  Mbandaka    F
# 4   Geoffrey   29    Bukavu    M
# 5  Khloranne   24  Kinshasa    F

# %%
df = pd.DataFrame(apprenants)

# %%
df
# Out:
#          Nom  âge     Ville Sexe
# 0    Harmony   28  Kinshasa    M
# 1      Sarah   25      Goma    F
# 2       Kiki   27    Kigali    F
# 3      Sally   23  Mbandaka    F
# 4   Geoffrey   29    Bukavu    M
# 5  Khloranne   24  Kinshasa    F

# %%
df.describe()
# Out:
#              âge
# count   6.000000
# mean   26.000000
# std     2.366432
# min    23.000000
# 25%    24.250000
# 50%    26.000000
# 75%    27.750000
# max    29.000000
